# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to the "***Sentiment Analysis and Classification Project***" project, the first and only project of the ***Natural Language Processing (NLP)*** course.
#
# This analysis will focus on using Natural Language techniques to find broad trends in the written thoughts of the customers.
# The goal in this project is to predict whether customers recommend the product they purchased using the information in their review text.
#
# One of the challenges in this project is to extract useful information from the *Review Text* variable using text mining techniques. The other challenge is that you need to convert text files into numeric feature vectors to run machine learning algorithms.
#
# At the end of this project, you will learn how to build sentiment classification models using Machine Learning algorithms (***Logistic Regression, Naive Bayes, Support Vector Machine, Random Forest*** and ***Ada Boosting***), **Deep Learning algorithms** and **BERT algorithm**.
#
# Before diving into the project, please take a look at the Determines and Tasks.
#
# - ***NOTE:*** *This tutorial assumes that you already know the basics of coding in Python and are familiar with the theory behind the algorithms mentioned above as well as NLP techniques.*

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
# The data is a collection of 22641 Rows and 10 column variables. Each row includes a written comment as well as additional customer information.
# Also each row corresponds to a customer review, and includes the variables:
#
#
# **Feature Information:**
#
# **Clothing ID:** Integer Categorical variable that refers to the specific piece being reviewed.
#
# **Age:** Positive Integer variable of the reviewers age.
#
# **Title:** String variable for the title of the review.
#
# **Review Text:** String variable for the review body.
#
# **Rating:** Positive Ordinal Integer variable for the product score granted by the customer from 1 Worst, to 5 Best.
#
# **Recommended IND:** Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended.
#
# **Positive Feedback Count:** Positive Integer documenting the number of other customers who found this review positive.
#
# **Division Name:** Categorical name of the product high level division.
#
# **Department Name:** Categorical name of the product department name.
#
# **Class Name:** Categorical name of the product class name.
#
# ---
#
# The basic goal in this project is to predict whether customers recommend the product they purchased using the information in their *Review Text*.
# Especially, it should be noted that the expectation in this project is to use only the "Review Text" variable and neglect the other ones.
# Of course, if you want, you can work on other variables individually.
#
# Project Structure is separated in five tasks: ***EDA, Feature Selection and Data Cleaning , Text Mining, Word Cloud*** and ***Sentiment Classification with Machine Learning, Deep Learning and BERT model***.
#
# Classically, you can start to know the data after doing the import and load operations.
# You need to do missing value detection for Review Text, which is the only variable you need to care about. You can drop other variables.
#
# You will need to apply ***noise removal*** and ***lexicon normalization*** processes by using the capabilities of the ***nltk*** library to the data set that is ready for text mining.
#
# Afterwards, you will implement ***Word Cloud*** as a visual analysis of word repetition.
#
# Finally, You will build models with five different algorithms and compare their performance. Thus, you will determine the algorithm that makes the most accurate emotion estimation by using the information obtained from the * Review Text * variable.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis
#
# - Import Modules, Load Discover the Data
#
# #### 2. Feature Selection and Data Cleaning
#
# - Feature Selection and Rename Column Name
# - Missing Value Detection
#
# #### 3. Text Mining
#
# - Tokenization
# - Noise Removal
# - Lexicon Normalization
#
# #### 4. WordCloud - Repetition of Words
#
# - Detect Reviews
# - Collect Words
# - Create Word Cloud
#
#
# #### 5. Sentiment Classification with Machine Learning, Deep Learning and BERT Model
#
# - Train - Test Split
# - Vectorization
# - TF-IDF
# - Logistic Regression
# - Naive Bayes
# - Support Vector Machine
# - Random Forest
# - AdaBoost
# - Deep Learning Model
# - BERT Model
# - Model Comparison

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Sentiment analysis of women's clothes reviews
#
#
# In this project we used sentiment analysis to determined whether the product is recommended or not. We used different machine learning algorithms to get more accurate predictions. The following classification algorithms have been used: ML algorithms(Logistic Regression, Naive Bayes, Support Vector Machine (SVM), Random Forest and Ada Boosting), Deep learning algorithm and BERT algorithm. The dataset comes from Woman Clothing Review that can be find at (https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews.

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %% [markdown]
# ### Import Libraries, Load and Discover the Data

# %%
# !pip install matplotlib -Uq

# %%
# !sudo update-alternatives --config python3
# Out:
# There are 3 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                Priority   Status
# ------------------------------------------------------------
#   0            /usr/bin/python3.9   2         auto mode
# * 1            /usr/bin/python3.6   1         manual mode
#   2            /usr/bin/python3.7   1         manual mode
#   3            /usr/bin/python3.9   2         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 2
# update-alternatives: using /usr/bin/python3.7 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.9
# Out:
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Hit:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# ...

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 2
# Out:
# update-alternatives: using /usr/bin/python3.9 to provide /usr/bin/python3 (python3) in auto mode

# %%
# !python --version
# Out:
# Python 3.7.15

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('display.max_columns', 50)

# %%
# !python --version
# Out:
# Python 3.9.15

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gdown
# same as the above, but with the file ID
id = "17YTKGaSbl8KyAu-OENrDnWBVcUYDY_EQ" # id: Womens Clothin...csv
output = 'Womens Clothing E-Commerce Reviews.csv' # download colab
gdown.download(id=id, output=output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17YTKGaSbl8KyAu-OENrDnWBVcUYDY_EQ
# To: /content/Womens Clothing E-Commerce Reviews.csv
# 100%|██████████| 8.48M/8.48M [00:00<00:00, 259MB/s]
# 'Womens Clothing E-Commerce Reviews.csv'

# %% [markdown]
# ### Data Wrangling

# %%
df = pd.read_csv("Womens Clothing E-Commerce Reviews.csv", index_col=0)
df.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23486 entries, 0 to 23485
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing ID              23486 non-null  int64
#  1   Age                      23486 non-null  int64
#  2   Title                    19676 non-null  object
#  3   Review Text              22641 non-null  object
#  4   Rating                   23486 non-null  int64
#  5   Recommended IND          23486 non-null  int64
#  6   Positive Feedback Count  23486 non-null  int64
#  7   Division Name            23472 non-null  object
#  8   Department Name          23472 non-null  object
#  9   Class Name               23472 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 2.0+ MB

# %%
sns.countplot(data =df, x ="Recommended IND")
plt.show()

# %%
sns.countplot(data = df, x ="Rating", hue = "Recommended IND");

# %%
ax = sns.countplot(data = df, x ="Department Name", hue = "Recommended IND")
#for p in ax.containers:
#    ax.bar_label(p)

# %% [markdown]
# #### Check Proportion of Target Class Variable:

# %% [markdown]
# The target class variable is imbalanced, where "Recommended" values are more dominating then "Not Recommendation".

# %%
df["Recommended IND"].value_counts()
# Out:
# 1    19314
# 0     4172
# Name: Recommended IND, dtype: int64

# %%
df["Recommended IND"].value_counts(normalize=True)
# Out:
# 1    0.822362
# 0    0.177638
# Name: Recommended IND, dtype: float64

# %% [markdown]
# ## 2. Feature Selection and Data Cleaning
#
# From now on, the DataFrame you will work with should contain two columns: **"Review Text"** and **"Recommended IND"**. You can do the missing value detection operations from now on. You can also rename the column names if you want.

# %% [markdown]
# ### Feature Selection and Rename Column Name

# %%
df2 = df.copy()

# %%
df2 = df2[["Review Text", "Recommended IND"]]

# %%
df2.rename(columns={"Review Text" : "review_text", "Recommended IND" : "recommended_ind"}, inplace=True)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Missing Value Detection

# %%
df2.isnull().sum()
# Out:
# review_text        845
# recommended_ind      0
# dtype: int64

# %%
df2.dropna(inplace=True)
df2 = df2.reset_index(drop=True)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 3. Text Mining
#
# Text is the most unstructured form of all the available data, therefore various types of noise are present in it. This means that the data is not readily analyzable without any pre-processing. The entire process of cleaning and standardization of text, making it noise-free and ready for analysis is known as **text preprocessing**.
#
# The three key steps of text preprocessing:
#
# - **Tokenization:**
# This step is one of the top priorities when it comes to working on text mining. Tokenization is essentially splitting a phrase, sentence, paragraph, or an entire text document into smaller units, such as individual words or terms. Each of these smaller units are called tokens.
#
# - **Noise Removal:**
# Any piece of text which is not relevant to the context of the data and the end-output can be specified as the noise.
# For example – language stopwords (commonly used words of a language – is, am, the, of, in etc), URLs or links, upper and lower case differentiation, punctuations and industry specific words. This step deals with removal of all types of noisy entities present in the text.
#
#
# - **Lexicon Normalization:**
# Another type of textual noise is about the multiple representations exhibited by single word.
# For example – “play”, “player”, “played”, “plays” and “playing” are the different variations of the word – “play”. Though they mean different things, contextually they all are similar. This step converts all the disparities of a word into their normalized form (also known as lemma).
# There are two methods of lexicon normalisation; **[Stemming or Lemmatization](https://www.guru99.com/stemming-lemmatization-python-nltk.html)**. Lemmatization is recommended for this case, because Lemmatization as this will return the root form of each word (rather than just stripping suffixes, which is stemming).
#
# As the first step change text to tokens and convertion all of the words to lower case.  Next remove punctuation, bad characters, numbers and stop words. The second step is aimed to normalization them throught the Lemmatization method.
#
#
# ***Note:*** *Use the functions of the ***[nltk Library](https://www.guru99.com/nltk-tutorial.html)*** for all the above operations.*

# %% [markdown]
# ### Tokenization, Noise Removal, Lexicon Normalization

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
def cleaning(data):
    
    import re
    
    #1. Removing URLS
    data = re.sub("(http\S+)|(www\S+)|(#\S+)|(@\S+)", '', data).strip()
       
    #4. Removing upper brackets to keep negative auxiliary verbs in text
    data = data.replace("'", "")
    
    #5. Tokenize
    text_tokens = word_tokenize(data.lower())
    
    #6. Remove Puncs and number
    tokens_without_punc = [w for w in text_tokens if w.isalpha()]
    
    #7. Removing Stopwords
    stop_words = stopwords.words('english')
    for i in ["not", "no"]:
        stop_words.remove(i)
    tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]
    
    #8. lemma
    text_cleaned = [WordNetLemmatizer().lemmatize(t) for t in tokens_without_sw]
    
    #joining
    return " ".join(text_cleaned)

# %%
df2["review_text_cl"] = df2["review_text"].apply(cleaning)
df2["review_text_cl"]
# Out:
# 0              absolutely wonderful silky sexy comfortable
# 1        love dress sooo pretty happened find store im ...
# 2        high hope dress really wanted work initially o...
# 3        love love love jumpsuit fun flirty fabulous ev...
# 4        shirt flattering due adjustable front tie perf...
#                                ...
# 22636    happy snag dress great price easy slip flatter...
# 22637    reminds maternity clothes soft stretchy shiny ...
# 22638    fit well top see never would worked im glad ab...
# 22639    bought dress wedding summer cute unfortunately...
# 22640    dress lovely platinum feminine fit perfectly e...
# Name: review_text_cl, Length: 22641, dtype: object

# %% [markdown]
# ## 4. WordCloud - Repetition of Words
#
# Now you'll create a Word Clouds for reviews, representing most common words in each target class.
#
# Word Cloud is a data visualization technique used for representing text data in which the size of each word indicates its frequency or importance. Significant textual data points can be highlighted using a word cloud.
#
# You are expected to create separate word clouds for positive and negative reviews. You can qualify a review as positive or negative, by looking at its recommended status. You may need to use capabilities of matplotlib for visualizations.
#
# You can follow the steps below:
#
# - Detect Reviews
# - Collect Words
# - Create Word Cloud

# %%
from wordcloud import WordCloud
from collections import Counter

# %% [markdown]
# ### Detect Reviews (positive and negative separately)

# %%
positives = df2[df2["recommended_ind"] == 1]["review_text_cl"]
negatives = df2[df2["recommended_ind"] == 0]["review_text_cl"]

# %%
positive_r = positives
negative_r = negatives

# %%
all_positives = " ".join(positive_r)
all_negatives = " ".join(negative_r)

# %%
all_positives[:100]
# Out:
# 'absolutely wonderful silky sexy comfortable love dress sooo pretty happened find store im glad bc ne'

# %%
all_negatives[:100]
# Out:
# 'high hope dress really wanted work initially ordered petite small usual size found outrageously smal'

# %% [markdown]
# ### Collect Words (positive and negative separately)

# %%
count_positive = Counter(word_tokenize(all_positives))
count_negative = Counter(word_tokenize(all_negatives))

# %%
count_positive.most_common()
# Out:
# [('dress', 9249),
#  ('fit', 8637),
#  ('love', 8062),
#  ('size', 8020),
#  ('not', 7428),
#  ('top', 6583),
#  ('color', 5903),
#  ('wear', 5739),
#  ('great', 5573),
#  ('look', 5308),
#  ('like', 5290),
#  ('im', 5046),
#  ('small', 3705),
#  ('would', 3704),
#  ('fabric', 3597),
#  ('perfect', 3560),
#  ('little', 3410),
#  ('really', 3055),
#  ('one', 3050),
#  ('flattering', 3035),
#  ('soft', 3030),
#  ('ordered', 3013),
#  ('comfortable', 2876),
#  ('well', 2817),
#  ('bought', 2683),
#  ('nice', 2603),
#  ('bit', 2567),
#  ('cute', 2495),
#  ('beautiful', 2481),
#  ('jean', 2414),
#  ('length', 2312),
#  ('run', 2264),
#  ('large', 2259),
#  ('sweater', 2204),
#  ('back', 2160),
#  ('got', 2124),
#  ('shirt', 2106),
#  ('petite', 2089),
#  ('long', 2066),
#  ('material', 2065),
#  ('work', 2001),
#  ('much', 1982),
#  ('medium', 1951),
#  ('also', 1943),
#  ('skirt', 1886),
#  ('short', 1862),
#  ('waist', 1860),
#  ('think', 1858),
#  ('x', 1785),
#  ('feel', 1775),
# ...

# %%
count_negative.most_common()
# Out:
# [('not', 2522),
#  ('dress', 2103),
#  ('like', 1746),
#  ('top', 1697),
#  ('look', 1582),
#  ('fit', 1490),
#  ('size', 1343),
#  ('would', 1310),
#  ('fabric', 1265),
#  ('back', 1026),
#  ('color', 1013),
#  ('love', 930),
#  ('im', 922),
#  ('small', 884),
#  ('really', 868),
#  ('ordered', 822),
#  ('wear', 781),
#  ('material', 746),
#  ('much', 721),
#  ('shirt', 685),
#  ('one', 653),
#  ('way', 649),
#  ('also', 640),
#  ('even', 601),
#  ('looked', 588),
#  ('didnt', 572),
#  ('quality', 556),
#  ('cute', 535),
#  ('large', 532),
#  ('great', 528),
#  ('work', 526),
#  ('made', 509),
#  ('short', 499),
#  ('sweater', 495),
#  ('however', 487),
#  ('wanted', 469),
#  ('beautiful', 469),
#  ('tried', 469),
#  ('could', 451),
#  ('no', 450),
#  ('flattering', 450),
#  ('waist', 446),
#  ('cut', 437),
#  ('well', 434),
#  ('retailer', 431),
#  ('model', 430),
#  ('pretty', 427),
#  ('big', 418),
#  ('nice', 414),
#  ('good', 399),
#  ('design', 398),
#  ('arm', 397),
# ...

# %% [markdown]
# ### Create Word Cloud (for most common words in recommended not recommended reviews separately)

# %%
wordcloud = WordCloud(background_color="black", max_words =250) #colormap, weight, height verilevbilir
wordcloud.generate(all_positives)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,12))
plt.imshow(wordcloud, interpolation="bilinear",)                 #interpolation : renklendirme
plt.axis("off")                                                   # Cerceve olsun mu?
plt.show()

# %%
wordcloud = WordCloud(background_color="black", max_words =250)
wordcloud.generate(all_negatives)

# %%
#print(wordcloud.words_)

# %%
plt.figure(figsize = (12,12))
plt.imshow(wordcloud, interpolation="bilinear",)                 #interpolation : renklendirme
plt.axis("off")                                                   # Cerceve olsun mu?
plt.show()

# %% [markdown]
# ## 5. Sentiment Classification with Machine Learning, Deep Learning and BERT model
#
# Before moving on to modeling, as data preprocessing steps you will need to perform **[vectorization](https://machinelearningmastery.com/prepare-text-data-machine-learning-scikit-learn/)** and **train-test split**. You have performed many times train test split process before.
# But you will perform the vectorization for the first time.
#
# Machine learning algorithms most often take numeric feature vectors as input. Thus, when working with text documents, you need a way to convert each document into a numeric vector. This process is known as text vectorization. Commonly used vectorization approach that you will use here is to represent each text as a vector of word counts.
#
# At this moment, you have your review text column as a token (which has no punctuations and stopwords). You can use Scikit-learn’s CountVectorizer to convert the text collection into a matrix of token counts. You can imagine this resulting matrix as a 2-D matrix, where each row is a unique word, and each column is a review.
#
# Train all models using TFIDF and Count vectorizer data.
#
# **For Deep learning model, use embedding layer for all words.**
#
# **For BERT model, use TF tensor**
#
# After performing data preprocessing, build your models using following classification algorithms:
#
# - Logistic Regression,
# - Naive Bayes,
# - Support Vector Machine,
# - Random Forest,
# - Ada Boosting
# - Deep Learning Model
# - BERT Model

# %%
df2.recommended_ind = df2.recommended_ind.map({1:0, 0:1})

# %% [markdown]
# ### Train - Test Split

# %% [markdown]
# To run machine learning algorithms we need to convert text files into numerical feature vectors. We will use bag of words model for our analysis.
#
# First we spliting the data into train and test sets:

# %%
from sklearn.model_selection import train_test_split

# %%
X=df2["review_text_cl"]
y=df2["recommended_ind"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, stratify=y, random_state=101)

# %%
X_train.shape, X_test.shape
# Out:
# ((19244,), (3397,))

# %% [markdown]
# In the next step we create a numerical feature vector for each document:

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score, recall_score
from sklearn.model_selection import cross_validate

# %%
def eval(model, X_train, X_test):
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    print(confusion_matrix(y_test, y_pred))
    print("Test_Set")
    print(classification_report(y_test,y_pred))
    print("Train_Set")
    print(classification_report(y_train,y_pred_train))

# %%
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

scoring = {'accuracy': make_scorer(accuracy_score),
            'precision': make_scorer(precision_score, average=None, labels=[1]),
            'recall': make_scorer(recall_score, average=None, labels = [1]),
            'f1-neg': make_scorer(f1_score, average=None, labels = [1])}

# %% [markdown]
# ### Count Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(min_df=3)
X_train_count = vectorizer.fit_transform(X_train)
X_test_count = vectorizer.transform(X_test)

# %%
X_train_count.shape, X_test_count.shape
# Out:
# ((19244, 5065), (3397, 5065))

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf_idf_vectorizer = TfidfVectorizer(min_df=3)
X_train_tf_idf = tf_idf_vectorizer.fit_transform(X_train)
X_test_tf_idf = tf_idf_vectorizer.transform(X_test)

# %%
X_train_tf_idf.shape, X_test_tf_idf.shape
# Out:
# ((19244, 5065), (3397, 5065))

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### CountVectorizer

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=101)
log.fit(X_train_count,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=101)

# %%
print("LOG MODEL")
eval(log, X_train_count, X_test_count)
# Out:
# LOG MODEL
# [[2473  309]
#  [ 126  489]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92      2782
#            1       0.61      0.80      0.69       615
#
#     accuracy                           0.87      3397
#    macro avg       0.78      0.84      0.81      3397
# weighted avg       0.89      0.87      0.88      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96     15758
#            1       0.73      0.97      0.83      3486
#
#     accuracy                           0.93     19244
#    macro avg       0.86      0.94      0.89     19244
# weighted avg       0.94      0.93      0.93     19244

# %%
model = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=101)
scores = cross_validate(model, X_train_count, y_train, scoring = scoring, cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.867648
# train_accuracy     0.933157
# test_precision     0.604387
# train_precision    0.741112
# test_recall        0.780554
# train_recall       0.969784
# test_f1-neg        0.681026
# train_f1-neg       0.840164
# dtype: float64

# %%
from sklearn.model_selection import GridSearchCV

model = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=101)
param_grid = {
    "C": [1, 0.03, 0.07, 0.01, 10],
    'penalty': ["l1", "l2"],
    'solver': ['liblinear', 'lbfgs'],
}
log_gridmodel = GridSearchCV(model,
             param_grid,
             verbose=3,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             n_jobs=-1, cv=10)
log_gridmodel.fit(X_train_count,y_train)
log_gridmodel.best_params_
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
print("LOG_GRID MODEL")
eval(log_gridmodel, X_train_count, X_test_count)
# Out:
# LOG_GRID MODEL
# [[2350  432]
#  [  90  525]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.84      0.90      2782
#            1       0.55      0.85      0.67       615
#
#     accuracy                           0.85      3397
#    macro avg       0.76      0.85      0.78      3397
# weighted avg       0.89      0.85      0.86      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91     15758
#            1       0.58      0.88      0.70      3486
#
#     accuracy                           0.86     19244
#    macro avg       0.77      0.87      0.80     19244
# weighted avg       0.90      0.86      0.87     19244

# %%
#!pip install scikit-plot
import scikitplot as skplt
y_probas = log_gridmodel.predict_proba(X_test_count)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()

# %%
#from sklearn.metrics import plot_precision_recall_curve
#plot_precision_recall_curve(log_gridmodel, X_test_count, y_test, pos_label=0);

# %%
y_pred = log_gridmodel.predict(X_test_count)
log_count_rec = recall_score(y_test, y_pred, labels = [1], average = None)
log_count_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
log_count_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=101)
log.fit(X_train_tf_idf,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=101)

# %%
print("LOG MODEL")
eval(log, X_train_tf_idf, X_test_tf_idf)
# Out:
# LOG MODEL
# [[2397  385]
#  [  88  527]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91      2782
#            1       0.58      0.86      0.69       615
#
#     accuracy                           0.86      3397
#    macro avg       0.77      0.86      0.80      3397
# weighted avg       0.89      0.86      0.87      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93     15758
#            1       0.64      0.93      0.76      3486
#
#     accuracy                           0.89     19244
#    macro avg       0.81      0.91      0.85     19244
# weighted avg       0.92      0.89      0.90     19244

# %%
model = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=101)
scores = cross_validate(model, X_train_tf_idf, y_train, scoring = scoring, cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.866660
# train_accuracy     0.894478
# test_precision     0.592077
# train_precision    0.644394
# test_recall        0.852840
# train_recall       0.931599
# test_f1-neg        0.698652
# train_f1-neg       0.761824
# dtype: float64

# %%
from sklearn.model_selection import GridSearchCV

model = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=101)
param_grid = {
    "C": [1, 0.3, 0.8, 0.1, 10],
    'penalty': ["l1", "l2"],
    'solver': ['liblinear', 'lbfgs'],
}
log_gridmodel_tf = GridSearchCV(model,
             param_grid,
             verbose=3,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             n_jobs=-1, cv=10)
log_gridmodel_tf.fit(X_train_tf_idf,y_train)
log_gridmodel_tf.best_params_
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
print("LOG_GRID MODEL")
eval(log_gridmodel_tf, X_train_tf_idf, X_test_tf_idf)
# Out:
# LOG_GRID MODEL
# [[2336  446]
#  [  84  531]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90      2782
#            1       0.54      0.86      0.67       615
#
#     accuracy                           0.84      3397
#    macro avg       0.75      0.85      0.78      3397
# weighted avg       0.89      0.84      0.86      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91     15758
#            1       0.57      0.89      0.70      3486
#
#     accuracy                           0.86     19244
#    macro avg       0.77      0.87      0.80     19244
# weighted avg       0.90      0.86      0.87     19244

# %%
y_probas = log_gridmodel_tf.predict_proba(X_test_tf_idf)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()

# %%
y_pred = log_gridmodel_tf.predict(X_test_tf_idf)
log_tfidf_rec = recall_score(y_test, y_pred, labels = [1], average = None)
log_tfidf_f1  = f1_score(y_test, y_pred, labels = [1], average = None)
log_tfidf_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ## Naive Bayes
#
# ### Countvectorizer

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
classes_weights
# Out:
# array([0.61061048, 0.61061048, 2.76018359, ..., 0.61061048, 0.61061048,
#        0.61061048])

# %%
nb = MultinomialNB(alpha=1)
nb.fit(X_train_count,y_train, sample_weight=classes_weights)
# Out:
# MultinomialNB(alpha=1)

# %%
print("NB MODEL")
eval(nb, X_train_count, X_test_count)
# Out:
# NB MODEL
# [[2376  406]
#  [  79  536]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91      2782
#            1       0.57      0.87      0.69       615
#
#     accuracy                           0.86      3397
#    macro avg       0.77      0.86      0.80      3397
# weighted avg       0.90      0.86      0.87      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92     15758
#            1       0.61      0.91      0.73      3486
#
#     accuracy                           0.88     19244
#    macro avg       0.79      0.89      0.82     19244
# weighted avg       0.91      0.88      0.89     19244

# %%
model = MultinomialNB(alpha=1)
scores = cross_validate(model, X_train_count, y_train, scoring = scoring, cv = 10, return_train_score=True, fit_params={"sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.858397
# train_accuracy     0.878282
# test_precision     0.573351
# train_precision    0.609116
# test_recall        0.857713
# train_recall       0.915758
# test_f1-neg        0.687122
# train_f1-neg       0.731602
# dtype: float64

# %%
from sklearn.model_selection import GridSearchCV

model = MultinomialNB()
param_grid = {
    "alpha": [1, 5, 10]}
nb_gridmodel = GridSearchCV(model,
             param_grid,
             verbose=3,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             n_jobs=-1, cv=5)
nb_gridmodel.fit(X_train_count,y_train, sample_weight=classes_weights)
nb_gridmodel.best_params_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# {'alpha': 10}

# %%
print("NB MODEL")
eval(nb_gridmodel, X_train_count, X_test_count)
# Out:
# NB MODEL
# [[2334  448]
#  [  71  544]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90      2782
#            1       0.55      0.88      0.68       615
#
#     accuracy                           0.85      3397
#    macro avg       0.76      0.86      0.79      3397
# weighted avg       0.89      0.85      0.86      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91     15758
#            1       0.58      0.91      0.71      3486
#
#     accuracy                           0.86     19244
#    macro avg       0.78      0.88      0.81     19244
# weighted avg       0.90      0.86      0.87     19244

# %%
y_probas = nb_gridmodel.predict_proba(X_test_count)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()

# %%
y_pred = nb_gridmodel.predict(X_test_count)
nb_count_rec = recall_score(y_test, y_pred, labels = [1], average = None)
nb_count_f1  = f1_score(y_test, y_pred, labels = [1], average = None)
nb_count_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
nb = BernoulliNB()
nb.fit(X_train_tf_idf,y_train, sample_weight=classes_weights)
# Out:
# BernoulliNB()

# %%
print("NB MODEL")
eval(nb, X_train_tf_idf, X_test_tf_idf)
# Out:
# NB MODEL
# [[2384  398]
#  [  86  529]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91      2782
#            1       0.57      0.86      0.69       615
#
#     accuracy                           0.86      3397
#    macro avg       0.77      0.86      0.80      3397
# weighted avg       0.89      0.86      0.87      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92     15758
#            1       0.61      0.92      0.73      3486
#
#     accuracy                           0.88     19244
#    macro avg       0.79      0.89      0.83     19244
# weighted avg       0.91      0.88      0.89     19244

# %%
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
scores = cross_validate(BernoulliNB(), X_train_tf_idf, y_train, scoring = scoring, cv = 10, 
                        fit_params= {"sample_weight" : classes_weights},
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.858553
# train_accuracy     0.879033
# test_precision     0.573542
# train_precision    0.610219
# test_recall        0.859721
# train_recall       0.919679
# test_f1-neg        0.687856
# train_f1-neg       0.733649
# dtype: float64

# %%
from sklearn.model_selection import GridSearchCV

model = BernoulliNB()
param_grid = {
    "alpha": [1, 0.3, 0.1, 0.5,2, 0.06, 0.08, 5,10]}
nb_gridmodel_tf = GridSearchCV(model,
             param_grid,
             verbose=3,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             n_jobs=-1, cv=5)
nb_gridmodel_tf.fit(X_train_tf_idf,y_train, sample_weight=classes_weights)
nb_gridmodel_tf.best_params_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# {'alpha': 5}

# %%
print("NB MODEL")
eval(nb_gridmodel_tf, X_train_tf_idf, X_test_tf_idf)
# Out:
# NB MODEL
# [[2369  413]
#  [  79  536]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91      2782
#            1       0.56      0.87      0.69       615
#
#     accuracy                           0.86      3397
#    macro avg       0.77      0.86      0.80      3397
# weighted avg       0.89      0.86      0.87      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91     15758
#            1       0.59      0.91      0.71      3486
#
#     accuracy                           0.87     19244
#    macro avg       0.78      0.88      0.81     19244
# weighted avg       0.91      0.87      0.88     19244

# %%
y_probas = nb_gridmodel_tf.predict_proba(X_test_tf_idf)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()

# %%
y_pred = nb_gridmodel_tf.predict(X_test_tf_idf)
nb_tfidf_rec = recall_score(y_test, y_pred, labels = [1], average = None)
nb_tfidf_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
nb_tfidf_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ## Support Vector Machine (SVM)
#
# ### Countvectorizer

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(class_weight='balanced', random_state=101)
svc.fit(X_train_count,y_train)
# Out:
# LinearSVC(class_weight='balanced', random_state=101)

# %%
print("SVC MODEL")
eval(svc, X_train_count, X_test_count)
# Out:
# SVC MODEL
# [[2474  308]
#  [ 179  436]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      2782
#            1       0.59      0.71      0.64       615
#
#     accuracy                           0.86      3397
#    macro avg       0.76      0.80      0.78      3397
# weighted avg       0.87      0.86      0.86      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     15758
#            1       0.82      0.98      0.89      3486
#
#     accuracy                           0.96     19244
#    macro avg       0.91      0.97      0.93     19244
# weighted avg       0.96      0.96      0.96     19244

# %%
model = LinearSVC(class_weight='balanced', random_state=101)
scores = cross_validate(model, X_train_count, y_train, scoring = scoring, cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.852319
# train_accuracy     0.962632
# test_precision     0.577169
# train_precision    0.836430
# test_recall        0.697084
# train_recall       0.986677
# test_f1-neg        0.631232
# train_f1-neg       0.905360
# dtype: float64

# %%
from sklearn.model_selection import GridSearchCV

model = LinearSVC(class_weight='balanced', random_state=101)
param_grid = {"C": [1, 0.002, 0.005, 0.05]}
svc_gridmodel = GridSearchCV(model,
             param_grid,
             verbose=3,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             n_jobs=-1, cv=10)
svc_gridmodel.fit(X_train_count,y_train)
svc_gridmodel.best_params_
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# {'C': 0.002}

# %%
print("SVC GRID MODEL")
eval(svc_gridmodel, X_train_count, X_test_count)
# Out:
# SVC GRID MODEL
# [[2373  409]
#  [  83  532]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91      2782
#            1       0.57      0.87      0.68       615
#
#     accuracy                           0.86      3397
#    macro avg       0.77      0.86      0.79      3397
# weighted avg       0.89      0.86      0.87      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92     15758
#            1       0.60      0.90      0.72      3486
#
#     accuracy                           0.87     19244
#    macro avg       0.79      0.88      0.82     19244
# weighted avg       0.91      0.87      0.88     19244

# %%
from sklearn.calibration import CalibratedClassifierCV

calibrated_svc = CalibratedClassifierCV(
    base_estimator=svc_gridmodel, 
    method='sigmoid',
    cv=4, 
)
calibrated_svc.fit(X_train_count, y_train)

y_probas = calibrated_svc.predict_proba(X_test_count)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Fitting 10 folds for each of 4 candidates, totalling 40 fits

# %%
from sklearn.metrics import plot_precision_recall_curve
plot_precision_recall_curve(svc_gridmodel, X_test_count, y_test, pos_label=1);
plt.show()

# %%
y_pred = svc_gridmodel.predict(X_test_count)
svc_count_rec = recall_score(y_test, y_pred, labels = [1], average = None)
svc_count_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
svc_count_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ### TD-IDF

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(class_weight='balanced', random_state=101)
svc.fit(X_train_tf_idf,y_train)
# Out:
# LinearSVC(class_weight='balanced', random_state=101)

# %%
print("SVC MODEL")
eval(svc, X_train_tf_idf, X_test_tf_idf)
# Out:
# SVC MODEL
# [[2450  332]
#  [ 118  497]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.92      2782
#            1       0.60      0.81      0.69       615
#
#     accuracy                           0.87      3397
#    macro avg       0.78      0.84      0.80      3397
# weighted avg       0.89      0.87      0.87      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95     15758
#            1       0.72      0.97      0.83      3486
#
#     accuracy                           0.93     19244
#    macro avg       0.86      0.95      0.89     19244
# weighted avg       0.94      0.93      0.93     19244

# %%
model = LinearSVC(class_weight='balanced', random_state=101)
scores = cross_validate(model, X_train_tf_idf, y_train, scoring = scoring, cv = 10,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.866245
# train_accuracy     0.930558
# test_precision     0.599714
# train_precision    0.731267
# test_recall        0.789737
# train_recall       0.974979
# test_f1-neg        0.681400
# train_f1-neg       0.835714
# dtype: float64

# %%
model = LinearSVC(class_weight='balanced', random_state=101)
param_grid = {
    "C": [1, 0.5, 0.3, 0.005,0.01, 0.05, 0.03, 0.1]}
svc_gridmodel_tf = GridSearchCV(model,
             param_grid,
             verbose=3,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             n_jobs=-1, cv=10)
svc_gridmodel_tf.fit(X_train_tf_idf,y_train)
svc_gridmodel_tf.best_params_
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# {'C': 0.01}

# %%
print("SVC GRID MODEL")
eval(svc_gridmodel_tf, X_train_tf_idf, X_test_tf_idf)
# Out:
# SVC GRID MODEL
# [[2331  451]
#  [  82  533]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90      2782
#            1       0.54      0.87      0.67       615
#
#     accuracy                           0.84      3397
#    macro avg       0.75      0.85      0.78      3397
# weighted avg       0.89      0.84      0.86      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91     15758
#            1       0.57      0.90      0.69      3486
#
#     accuracy                           0.86     19244
#    macro avg       0.77      0.87      0.80     19244
# weighted avg       0.90      0.86      0.87     19244

# %%
from sklearn.calibration import CalibratedClassifierCV

calibrated_svc = CalibratedClassifierCV(
    base_estimator=svc_gridmodel_tf, 
    method='sigmoid',
    cv=4, 
)
calibrated_svc.fit(X_train_tf_idf, y_train)

y_probas = calibrated_svc.predict_proba(X_test_tf_idf)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# Fitting 10 folds for each of 8 candidates, totalling 80 fits

# %%
#plot_precision_recall_curve(svc_gridmodel_tf, X_test_tf_idf, y_test, pos_label=1);
#plt.show()

# %%
y_pred = svc_gridmodel_tf.predict(X_test_tf_idf)
svc_tfidf_rec = recall_score(y_test, y_pred, labels = [1], average = None)
svc_tfidf_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
svc_tfidf_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ## Random Forest
#
# ### Countvectorizer

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state = 101, class_weight="balanced")
rf.fit(X_train_count, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=101)

# %%
print("RF MODEL")
eval(rf, X_train_count, X_test_count)
# Out:
# RF MODEL
# [[2745   37]
#  [ 446  169]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      2782
#            1       0.82      0.27      0.41       615
#
#     accuracy                           0.86      3397
#    macro avg       0.84      0.63      0.67      3397
# weighted avg       0.85      0.86      0.83      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15758
#            1       1.00      1.00      1.00      3486
#
#     accuracy                           1.00     19244
#    macro avg       1.00      1.00      1.00     19244
# weighted avg       1.00      1.00      1.00     19244

# %%
model = RandomForestClassifier(class_weight='balanced', random_state = 101)
scores = cross_validate(model, X_train_count, y_train, scoring=scoring, cv = 5, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.858606
# train_accuracy     1.000000
# test_precision     0.844350
# train_precision    1.000000
# test_recall        0.269372
# train_recall       1.000000
# test_f1-neg        0.407929
# train_f1-neg       1.000000
# dtype: float64

# %%
model = RandomForestClassifier(class_weight="balanced", random_state = 101, )
param_grid = {
    "n_estimators": [100, 150,200],
    "max_depth" : [10,5,3],
    #"max_samples" : [0.3, 0.2, 0.5]
}
rf_gridmodel = GridSearchCV(model,
             param_grid,
             #verbose=3,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             cv=5)
rf_gridmodel.fit(X_train_count,y_train)
rf_gridmodel.best_params_
# Out:
# {'max_depth': 3, 'n_estimators': 200}

# %%
print("RF MODEL")
eval(rf_gridmodel, X_train_count, X_test_count)
# Out:
# RF MODEL
# [[2238  544]
#  [ 111  504]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87      2782
#            1       0.48      0.82      0.61       615
#
#     accuracy                           0.81      3397
#    macro avg       0.72      0.81      0.74      3397
# weighted avg       0.87      0.81      0.82      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.80      0.87     15758
#            1       0.48      0.84      0.61      3486
#
#     accuracy                           0.81     19244
#    macro avg       0.72      0.82      0.74     19244
# weighted avg       0.87      0.81      0.82     19244

# %%
y_probas = rf_gridmodel.predict_proba(X_test_count)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()

# %%
y_pred = rf_gridmodel.predict(X_test_count)
rf_count_rec = recall_score(y_test, y_pred, labels = [1], average = None)
rf_count_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
rf_count_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ### TF-IDF

# %%
rf = RandomForestClassifier(random_state = 101, class_weight="balanced")
rf.fit(X_train_tf_idf, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=101)

# %%
print("RF MODEL")
eval(rf, X_train_tf_idf, X_test_tf_idf)
# Out:
# RF MODEL
# [[2747   35]
#  [ 440  175]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      2782
#            1       0.83      0.28      0.42       615
#
#     accuracy                           0.86      3397
#    macro avg       0.85      0.64      0.67      3397
# weighted avg       0.86      0.86      0.83      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15758
#            1       1.00      1.00      1.00      3486
#
#     accuracy                           1.00     19244
#    macro avg       1.00      1.00      1.00     19244
# weighted avg       1.00      1.00      1.00     19244

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101)
scores = cross_validate(model, X_train_tf_idf, y_train, scoring = scoring, cv = 5, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.859229
# train_accuracy     1.000000
# test_precision     0.836401
# train_precision    1.000000
# test_recall        0.277690
# train_recall       1.000000
# test_f1-neg        0.416403
# train_f1-neg       1.000000
# dtype: float64

# %%
model = RandomForestClassifier(class_weight="balanced", random_state = 101)
param_grid = {
    "n_estimators": [100, 150, 200],
    "max_depth" : [2,3,5]
}
rf_gridmodel_tf = GridSearchCV(model,
             param_grid,
             #verbose=5,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             cv=5)
rf_gridmodel_tf.fit(X_train_tf_idf,y_train)
rf_gridmodel_tf.best_params_
# Out:
# {'max_depth': 3, 'n_estimators': 200}

# %%
print("RF MODEL")
eval(rf_gridmodel_tf, X_train_tf_idf, X_test_tf_idf)
# Out:
# RF MODEL
# [[2194  588]
#  [ 105  510]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86      2782
#            1       0.46      0.83      0.60       615
#
#     accuracy                           0.80      3397
#    macro avg       0.71      0.81      0.73      3397
# weighted avg       0.87      0.80      0.82      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87     15758
#            1       0.48      0.86      0.61      3486
#
#     accuracy                           0.80     19244
#    macro avg       0.72      0.82      0.74     19244
# weighted avg       0.87      0.80      0.82     19244

# %%
y_probas = rf_gridmodel_tf.predict_proba(X_test_tf_idf)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()

# %%
y_pred = rf_gridmodel_tf.predict(X_test_tf_idf)
rf_tfidf_rec = recall_score(y_test, y_pred, labels = [1], average = None)
rf_tfidf_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
rf_tfidf_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ## Ada Boosting
#
# ### Countvectorizer

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(random_state = 101)
ada.fit(X_train_count, y_train, sample_weight=classes_weights)
# Out:
# AdaBoostClassifier(random_state=101)

# %%
print("Ada MODEL")
eval(ada, X_train_count, X_test_count)
# Out:
# Ada MODEL
# [[2307  475]
#  [ 139  476]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      2782
#            1       0.50      0.77      0.61       615
#
#     accuracy                           0.82      3397
#    macro avg       0.72      0.80      0.75      3397
# weighted avg       0.86      0.82      0.83      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.88     15758
#            1       0.50      0.78      0.61      3486
#
#     accuracy                           0.82     19244
#    macro avg       0.72      0.81      0.75     19244
# weighted avg       0.86      0.82      0.83     19244

# %%
model = AdaBoostClassifier(random_state = 101)
scores = cross_validate(model, X_train_count, y_train, scoring = scoring, cv = 5, return_train_score=True, fit_params={"sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.812877
# train_accuracy     0.820502
# test_precision     0.489471
# train_precision    0.502923
# test_recall        0.766781
# train_recall       0.785786
# test_f1-neg        0.597464
# train_f1-neg       0.613306
# dtype: float64

# %%
model = AdaBoostClassifier(random_state = 101)
param_grid = {
    "n_estimators": [100, 150,200],
    "learning_rate" : [1,0.5,0.3]
}
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
ada_gridmodel = GridSearchCV(model,
             param_grid,
             #verbose=5,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             cv=5)
ada_gridmodel.fit(X_train_count,y_train, sample_weight=classes_weights)
ada_gridmodel.best_params_
# Out:
# {'learning_rate': 0.5, 'n_estimators': 200}

# %%
print("Ada MODEL")
eval(ada_gridmodel, X_train_count, X_test_count)
# Out:
# Ada MODEL
# [[2359  423]
#  [  95  520]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90      2782
#            1       0.55      0.85      0.67       615
#
#     accuracy                           0.85      3397
#    macro avg       0.76      0.85      0.78      3397
# weighted avg       0.89      0.85      0.86      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90     15758
#            1       0.56      0.86      0.68      3486
#
#     accuracy                           0.85     19244
#    macro avg       0.76      0.86      0.79     19244
# weighted avg       0.89      0.85      0.86     19244

# %%
y_probas = ada_gridmodel.predict_proba(X_test_count)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()

# %%
y_pred = ada_gridmodel.predict(X_test_count)
ada_count_rec = recall_score(y_test, y_pred, labels = [1], average = None)
ada_count_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
ada_count_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ### TF-IDF

# %%
ada = AdaBoostClassifier(random_state = 101)
ada.fit(X_train_tf_idf, y_train, sample_weight=classes_weights)
# Out:
# AdaBoostClassifier(random_state=101)

# %%
print("Ada MODEL")
eval(ada, X_train_tf_idf, X_test_tf_idf)
# Out:
# Ada MODEL
# [[2277  505]
#  [ 161  454]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      2782
#            1       0.47      0.74      0.58       615
#
#     accuracy                           0.80      3397
#    macro avg       0.70      0.78      0.72      3397
# weighted avg       0.85      0.80      0.82      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88     15758
#            1       0.50      0.78      0.61      3486
#
#     accuracy                           0.82     19244
#    macro avg       0.72      0.81      0.75     19244
# weighted avg       0.87      0.82      0.83     19244

# %%
model = AdaBoostClassifier(random_state = 101)
scores = cross_validate(model, X_train_tf_idf, y_train, scoring = scoring, cv = 5, return_train_score = True, fit_params={"sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_accuracy      0.794429
# train_accuracy     0.805888
# test_precision     0.460838
# train_precision    0.479679
# test_recall        0.780547
# train_recall       0.814329
# test_f1-neg        0.579278
# train_f1-neg       0.603334
# dtype: float64

# %%
model = AdaBoostClassifier(random_state = 101)
param_grid = {
    "n_estimators": [150, 200],
    "learning_rate" : [1,0.5,0.3, 0.1]
}
#classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
ada_gridmodel_tf = GridSearchCV(model,
             param_grid,
             #verbose=5,
             scoring=make_scorer(recall_score, average=None, labels = [1]),
             cv=5)
ada_gridmodel_tf.fit(X_train_tf_idf,y_train, sample_weight=classes_weights)
ada_gridmodel_tf.best_params_
# Out:
# {'learning_rate': 0.3, 'n_estimators': 150}

# %%
print("Ada MODEL")
eval(ada_gridmodel_tf, X_train_tf_idf, X_test_tf_idf)
# Out:
# Ada MODEL
# [[2256  526]
#  [ 108  507]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.88      2782
#            1       0.49      0.82      0.62       615
#
#     accuracy                           0.81      3397
#    macro avg       0.72      0.82      0.75      3397
# weighted avg       0.87      0.81      0.83      3397
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.89     15758
#            1       0.52      0.86      0.64      3486
#
#     accuracy                           0.83     19244
#    macro avg       0.74      0.84      0.77     19244
# weighted avg       0.88      0.83      0.84     19244

# %%
y_probas = ada_gridmodel_tf.predict_proba(X_test_tf_idf)
skplt.metrics.plot_precision_recall(y_test, y_probas)
plt.show()

# %%
y_pred = ada_gridmodel_tf.predict(X_test_tf_idf)
ada_tfidf_rec = recall_score(y_test, y_pred, labels = [1], average = None)
ada_tfidf_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
ada_tfidf_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ## DL modeling

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Embedding, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
df3 = pd.DataFrame(df[["Recommended IND", "Review Text"]].values, columns=['recommended_ind', 'review_text'])
df3['recommended_ind'] = df3['recommended_ind'].map({0 : 1, 1: 0})
df3 = df3.dropna().reset_index(drop=True)

# %%
X=df3["review_text"]
y=df3["recommended_ind"]

# %% [markdown]
# ### Tokenization

# %%
tokenizer = Tokenizer()

# %%
len(df3)
# Out:
# 22641

# %%
tokenizer.fit_on_texts(X)

# %% [markdown]
# ### Creating word index

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'i': 2,
#  'and': 3,
#  'a': 4,
#  'it': 5,
#  'is': 6,
#  'this': 7,
#  'to': 8,
#  'in': 9,
#  'but': 10,
#  'on': 11,
#  'for': 12,
#  'of': 13,
#  'with': 14,
#  'was': 15,
#  'so': 16,
#  'my': 17,
#  'dress': 18,
#  'not': 19,
#  'that': 20,
#  'love': 21,
#  'size': 22,
#  'very': 23,
#  'have': 24,
#  'top': 25,
#  'fit': 26,
#  'are': 27,
#  'like': 28,
#  'be': 29,
#  'as': 30,
#  'me': 31,
#  'wear': 32,
#  "it's": 33,
#  'great': 34,
#  'too': 35,
#  "i'm": 36,
#  'or': 37,
#  'am': 38,
#  'just': 39,
#  'you': 40,
#  'would': 41,
#  'they': 42,
#  'up': 43,
#  'at': 44,
#  'fabric': 45,
#  'small': 46,
#  'color': 47,
#  'look': 48,
#  'if': 49,
#  'more': 50,
#  'really': 51,
#  'ordered': 52,
#  'little': 53,
#  'perfect': 54,
#  'will': 55,
#  'one': 56,
#  'these': 57,
#  'flattering': 58,
#  'well': 59,
#  'an': 60,
#  'soft': 61,
#  'out': 62,
#  'back': 63,
#  'because': 64,
#  'had': 65,
#  'can': 66,
#  '\r': 67,
#  'comfortable': 68,
# ...

# %%
len(tokenizer.word_index)
# Out:
# 14847

# %% [markdown]
# ### Converting tokens to numeric

# %%
X_num_tokens = tokenizer.texts_to_sequences(X)

# %% [markdown]
# ### Maximum number of tokens for all documents¶

# %%
num_tokens = [len(tokens) for tokens in X_num_tokens]
num_tokens = np.array(num_tokens)

# %%
num_tokens
# Out:
# array([ 7, 62, 97, ..., 42, 85, 19])

# %%
len(X_num_tokens)
# Out:
# 22641

# %%
num_tokens.mean()
# Out:
# 60.60699615741354

# %%
num_tokens.max()
# Out:
# 116

# %%
max_tokens = 117

# %%
sum(num_tokens < max_tokens) / len(num_tokens)
# Out:
# 1.0

# %%
sum(num_tokens < max_tokens)
# Out:
# 22641

# %% [markdown]
# ### Fixing token counts of all documents (pad_sequences)

# %%
X_pad = pad_sequences(X_num_tokens, maxlen=max_tokens)

# %% [markdown]
# ### Train Set Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pad, y, test_size=0.15, stratify=y, random_state=101)

# %%
X_train.shape, X_test.shape
# Out:
# ((19244, 117), (3397, 117))

# %%
len(num_tokens)
# Out:
# 22641

# %%
X_pad.shape[0], len(num_tokens)
# Out:
# (22641, 22641)

# %% [markdown]
# ### Modeling

# %%
model = Sequential()
embedding_size = 40 #50,100,300
#num_words = 15000
num_words=len(tokenizer.word_index)+1
model.add(Embedding(input_dim=num_words,
                    output_dim=embedding_size,
                    input_length=max_tokens))

model.add(Dropout(0.2))

model.add(GRU(units=32, return_sequences=True))
model.add(Dropout(0.2))

#model.add(GRU(units=24, return_sequences=True))
#model.add(Dropout(0.2))

model.add(GRU(units=16)) 

model.add(Dense(1, activation='sigmoid'))

# %%
optimizer = Adam(learning_rate=0.003)

model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['Recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 117, 40)           593920
#
#  dropout (Dropout)           (None, 117, 40)           0
#
#  gru (GRU)                   (None, 117, 32)           7104
#
#  dropout_1 (Dropout)         (None, 117, 32)           0
#
#  gru_1 (GRU)                 (None, 16)                2400
#
#  dense (Dense)               (None, 1)                 17
#
# ...
# Total params: 603,441
# Trainable params: 603,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor="val_recall", mode="max", 
                           verbose=1, patience = 2, restore_best_weights=True)

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)

# %%
model.fit(X_train, y_train, epochs=10, batch_size=64, sample_weight= classes_weights,
         validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/10
# 301/301 [==============================] - 13s 16ms/step - loss: 0.4442 - recall: 0.8210 - val_loss: 0.4563 - val_recall: 0.9285
# Epoch 2/10
# 301/301 [==============================] - 5s 15ms/step - loss: 0.2781 - recall: 0.9185 - val_loss: 0.4725 - val_recall: 0.9285
# Epoch 3/10
# ...
# 301/301 [==============================] - 5s 17ms/step - loss: 0.2133 - recall: 0.9464 - val_loss: 0.3442 - val_recall: 0.8488
# Epoch 3: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.head()
# Out:
#        loss    recall  val_loss  val_recall
# 0  0.444235  0.820998  0.456343    0.928455
# 1  0.278100  0.918531  0.472496    0.928455
# 2  0.213291  0.946357  0.344198    0.848781

# %%
model.evaluate(X_test, y_test)
# Out:
# 107/107 [==============================] - 1s 6ms/step - loss: 0.4563 - recall: 0.9285
# [0.4563427269458771, 0.9284552931785583]

# %%
model.evaluate(X_train, y_train)
# Out:
# 602/602 [==============================] - 5s 8ms/step - loss: 0.3995 - recall: 0.9693
# [0.3994602560997009, 0.9693058133125305]

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, roc_auc_score

y_pred = model.predict(X_test) >= 0.5

print("TEST")
print(confusion_matrix(y_test, y_pred))
print("-------------------------------------------------------")
print(classification_report(y_test, y_pred))

y_pred_train = model.predict(X_train) >= 0.5

print("TRAIN")
print(confusion_matrix(y_train, y_pred_train))
print("-------------------------------------------------------")
print(classification_report(y_train, y_pred_train))
# Out:
# 107/107 [==============================] - 1s 5ms/step
# TEST
# [[2088  694]
#  [  44  571]]
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.75      0.85      2782
#            1       0.45      0.93      0.61       615
#
#     accuracy                           0.78      3397
#    macro avg       0.72      0.84      0.73      3397
# weighted avg       0.88      0.78      0.81      3397
#
# 602/602 [==============================] - 3s 5ms/step
# TRAIN
# [[12313  3445]
#  [  107  3379]]
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      0.78      0.87     15758
#            1       0.50      0.97      0.66      3486
#
#     accuracy                           0.82     19244
#    macro avg       0.74      0.88      0.76     19244
# weighted avg       0.90      0.82      0.83     19244

# %%
#model.save('dlmodel1.h5')

# %%
model.save('/content/drive/MyDrive/Proje/Sentiment_Analysis/sentiment_analysis_gru_2.h5')

# %%
model_loss.plot()

# %%
from sklearn.metrics import (precision_recall_curve,
                             PrecisionRecallDisplay)
y_pred_proba = model.predict(X_test)
PrecisionRecallDisplay.from_predictions(y_test, y_pred_proba)
plt.show()
# Out:
# 107/107 [==============================] - 1s 6ms/step

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

y_pred_proba = model.predict(X_test)
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot([1,0],[0,1],'k--')
plt.plot(recall, precision)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('precision recall curve')
plt.show()
# Out:
# 107/107 [==============================] - 1s 5ms/step

# %%
dl_gru_rec = recall_score(y_test, y_pred, labels = [1], average = None)
dl_gru_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
dl_gru_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ## BERT Modeling

# %%
import tensorflow as tf
import os #TPU sadece tensorflow kütüphanesinde çalışır.

# Note that the `tpu` argument is for Colab-only
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 39.2 MB/s
# ...
#      |████████████████████████████████| 163 kB 67.5 MB/s
# ...

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Womens Clothing E-Commerce Reviews.csv')

# %%
df4 = pd.DataFrame(df[["Recommended IND", "Review Text"]].values, columns=['recommended', 'review_text'])
df4['not_recommended'] = df4['recommended'].map({0 : 1, 1: 0})
df4 = df4.dropna().reset_index(drop=True)
df4.head()
# Out:
#   recommended                                        review_text  \
# 0           1  Absolutely wonderful - silky and sexy and comf...
# 1           1  Love this dress!  it's sooo pretty.  i happene...
# 2           0  I had such high hopes for this dress and reall...
# 3           1  I love, love, love this jumpsuit. it's fun, fl...
# 4           1  This shirt is very flattering to all due to th...
#
#    not_recommended
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0

# %%
X = df4['review_text'].values
y = df4['not_recommended'].values

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=101)

# %% [markdown]
# ### Tokenization

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# ### Transformation text to tensor

# %%
max_token = []
for sent in X:

    # Tokenize the text and add `[CLS]` and `[SEP]` tokens.
    
    input_ids = tokenizer.encode(sent, add_special_tokens=True)
    max_token.append(len(input_ids))

print('Max sentence length: ', max(max_token))
# Out:
# Max sentence length:  162

# %%
arr = np.array(max_token)
 
print("Descriptive analysis")
print("Document Size \t=", arr.shape[0])
print("Doc Token Count\t=", arr)

# measures of central tendency
print("Measures of Central Tendency")
print("Mean \t\t=", arr.mean())
print("Median \t\t=", np.median(arr))
#print("Mode \t\t=", stats.mode(arr)[0][0])

# measures of dispersion
print("Measures of Dispersion")
print("Minimum \t=", arr.min())
print("Maximum \t=", arr.max())
print("Range \t\t=", arr.ptp())
print("Variance \t=", arr.var())
print("Standard Deviation =", arr.std())
# Out:
# Descriptive analysis
# Document Size 	= 22641
# Doc Token Count	= [ 10  82 118 ...  54 102  26]
# Measures of Central Tendency
# Mean 		= 76.75659202332052
# Median 		= 75.0
# Measures of Dispersion
# Minimum 	= 4
# Maximum 	= 162
# Range 		= 158
# Variance 	= 1251.4350770125225
# Standard Deviation = 35.37562829141728

# %%
sum(np.array(max_token) < 163) / len(max_token)
# Out:
# 1.0

# %% [markdown]
# ### Transformation Vectors to Matrices

# %%
def transformation(X):  #vektörlerden matrikslere dönüştürme işlemi
  # set array dimensions
  seq_len = 163
  num_samples = len(X)

  # initialize empty zero arrays
  Xids = np.zeros((num_samples, seq_len))
  Xmask = np.zeros((num_samples, seq_len))

    
  for i, phrase in enumerate(X):
      tokens = tokenizer.encode_plus(phrase, max_length=seq_len, truncation=True,
                                      padding='max_length', add_special_tokens=True) 
      
      # assign tokenized outputs to respective rows in numpy arrays
      Xids[i] = tokens['input_ids']
      Xmask[i] = tokens['attention_mask']
  return Xids, Xmask

# %%
Xids_train, Xmask_train = transformation(X_train)

Xids_test, Xmask_test = transformation(X_test)

# %%
print("Xids_train.shape  :", Xids_train.shape)
print("Xmask_train.shape :", Xmask_train.shape)
print("Xids_test.shape   :", Xids_test.shape)
print("Xmask_test.shape  :", Xmask_test.shape)
# Out:
# Xids_train.shape  : (20376, 163)
# Xmask_train.shape : (20376, 163)
# Xids_test.shape   : (2265, 163)
# Xmask_test.shape  : (2265, 163)

# %%
labels_train = y_train.reshape(-1,1) #label ımızı da matrise dönüştürüyoruz. -1:satır sayımı sabit tut, 1: 1 boyut ekle
labels_train
# Out:
# array([[1],
#        [1],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
labels_test = y_test.reshape(-1,1)
labels_test
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]])

# %% [markdown]
# ## Transformation Matrix to Tensor

# %%
import tensorflow as tf

dataset_train = tf.data.Dataset.from_tensor_slices((Xids_train, Xmask_train, labels_train))
dataset_train
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(163,), dtype=tf.float64, name=None), TensorSpec(shape=(163,), dtype=tf.float64, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))>

# %%
dataset_test = tf.data.Dataset.from_tensor_slices((Xids_test, Xmask_test, labels_test))
dataset_test
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(163,), dtype=tf.float64, name=None), TensorSpec(shape=(163,), dtype=tf.float64, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))>

# %%
def map_func(Xids, Xmask, labels):
    # we convert our three-item tuple into a two-item tuple where the input item is a dictionary
    #input_ids ve attention_mask {} içine almak önemli
    return {'input_ids': Xids, 'attention_mask': Xmask}, labels

# %%
dataset_train = dataset_train.map(map_func)
dataset_test = dataset_test.map(map_func)

# %% [markdown]
# ### Batch Size

# %%
batch_size = 32 # 16, 32 
#overfitting i engelleyemezsek 64 yapılabilir, ancak 32 veya 16 kullanmak genelde yeterli olur

# batch_size 
# fit into a batch of 32
train_ds = dataset_train.batch(batch_size) # Gözlemlerin yeri sabit olduğundan metricler için kullanacağız. 
val_ds = dataset_test.batch(batch_size)

length = len(X_train)
train_ds2 = dataset_train.shuffle(buffer_size = length, reshuffle_each_iteration=True).batch(batch_size)

# %% [markdown]
# ### Creating Model

# %%
def create_model():
    from transformers import TFAutoModel #Sadece AutoModel olarak da import edebiliriz, tensorflow kullandığımız belli olsun diye başına TF yazdık. Yoksa hiç bir farkı yok.
    model = TFAutoModel.from_pretrained("bert-base-uncased")
    input_ids = tf.keras.layers.Input(shape=(163,), name='input_ids', dtype='int32')
    attention_mask = tf.keras.layers.Input(shape=(163,), name='attention_mask', dtype='int32')

    embeddings = model.bert(input_ids=input_ids, attention_mask=attention_mask)["pooler_output"] #Sayısla verilere denk gelen word embeddinglerimi çekmek için pooler_output aklımıza gelmezse, [1] de yazabiliriz.

    x = tf.keras.layers.Dense(163, activation='relu')(embeddings)
    x = tf.keras.layers.Dropout(0.1, name="dropout")(x) #Developer lar tarafından tavsiye edilen "0.1" dir.
    y = tf.keras.layers.Dense(1, activation='sigmoid', name='outputs')(x)

    return tf.keras.Model(inputs=[input_ids, attention_mask], outputs=y)

# %%
with strategy.scope():
  
  optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5) #3e-5, 5e-5
  loss = tf.keras.losses.BinaryCrossentropy()
  recall = tf.keras.metrics.Recall()
  model3 = create_model()
  model3.compile(optimizer=optimizer, loss=loss, metrics=["Recall"])
# Out:
# Downloading:   0%|          | 0.00/536M [00:00<?, ?B/s]
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model3.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_ids (InputLayer)         [(None, 163)]        0           []
#
#  attention_mask (InputLayer)    [(None, 163)]        0           []
#
#  bert (TFBertMainLayer)         TFBaseModelOutputWi  109482240   ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 163,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
# ...

# %%
from sklearn.utils import class_weight 

class_weights = dict(
    zip(np.unique(y_train),
        class_weight.compute_class_weight(
            class_weight = 'balanced',
            classes = np.unique(y_train), 
            y = y_train)
))
class_weights
# Out:
# {0: 0.6106083308360803, 1: 2.760227580601463}

# %%
history = model3.fit(train_ds2, validation_data= val_ds, class_weight= {0:1, 1:4}, 
                     epochs=1)
# Out:
# 637/637 [==============================] - 212s 190ms/step - loss: 0.4721 - recall: 0.8811 - val_loss: 0.2184 - val_recall: 0.9122

# %% [markdown]
# ### Model evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model3.predict(val_ds) >= 0.5

#print("Bert_sentiment_model: test_size:0.1")
print("TEST")
print(classification_report(y_test, y_pred))
print("--"*10)

y_train_pred = model3.predict(train_ds) >= 0.5

print("TRAIN")
print(classification_report(y_train, y_train_pred))
# Out:
# 71/71 [==============================] - 12s 103ms/step
# TEST
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94      1855
#            1       0.67      0.91      0.77       410
#
#     accuracy                           0.90      2265
#    macro avg       0.83      0.91      0.86      2265
# weighted avg       0.92      0.90      0.91      2265
#
# --------------------
# 637/637 [==============================] - 25s 37ms/step
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96     16685
#            1       0.73      0.97      0.83      3691
#
#     accuracy                           0.93     20376
#    macro avg       0.86      0.94      0.90     20376
# weighted avg       0.95      0.93      0.93     20376

# %%
model3.save('/content/drive/MyDrive/Proje/Sentiment_Analysis/sentiment_analysis_bert.h5')

# %%
from sklearn.metrics import PrecisionRecallDisplay
import matplotlib.pyplot as plt

y_pred_proba = model3.predict(val_ds)

PrecisionRecallDisplay.from_predictions(y_test, y_pred_proba)
plt.show();
# Out:
# 71/71 [==============================] - 4s 42ms/step

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

# %%
bert_rec = recall_score(y_test, y_pred, labels = [1], average = None)
bert_f1 = f1_score(y_test, y_pred, labels = [1], average = None)
bert_acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# ### Compare Models F1 Scores, Recall Scores and Average Precision Score

# %%
compare = pd.DataFrame({"Model": ["NaiveBayes_count", "LogReg_count", "SVM_count", "KNN_count", "Random Forest_count", 
                                  "AdaBoost_count", "NaiveBayes_tfidf", "LogReg_tfidf", "SVM_tfidf", "KNN_tfidf", 
                                  "Random Forest_tfidf", "AdaBoost_tfidf"],
                        
                        "F1_Score": [nb_count_f1[0], log_count_f1[0], svc_count_f1[0], rf_count_f1, ada_count_f1[0], nb_tfidf_f1[0], log_tfidf_f1[0],
                                             svc_tfidf_f1[0], rf_tfidf_f1[0], ada_tfidf_f1[0]],
                        
                        "Recall_Score": [nb_count_rec[0], log_count_rec[0], svc_count_rec[0], 
                                                  rf_count_rec[0], ada_count_rec[0], 
                                                  nb_tfidf_rec[0], log_tfidf_rec[0], svc_tfidf_rec[0], 
                                                  rf_tfidf_rec[0], ada_tfidf_rec[0]],
                        
                        "Accuracy_Score": [nb_count_acc[0], log_count_acc[0], svc_count_acc[0], 
                                                  rf_count_acc[0], ada_count_acc[0], 
                                                  nb_tfidf_acc[0], log_tfidf_acc[0], svc_tfidf_acc[0], 
                                                  rf_tfidf_acc[0], ada_tfidf_acc[0]]})
compare
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b68769184120> in <module>
# ----> 1 compare = pd.DataFrame({"Model": ["NaiveBayes_count", "LogReg_count", "SVM_count", "KNN_count", "Random Forest_count",
#       2                                   "AdaBoost_count", "NaiveBayes_tfidf", "LogReg_tfidf", "SVM_tfidf", "KNN_tfidf",
#       3                                   "Random Forest_tfidf", "AdaBoost_tfidf"],
#       4
#       5                         "F1_Score": [nb_count_f1[0], log_count_f1[0], svc_count_f1[0], rf_count_f1, ada_count_f1[0], nb_tfidf_f1[0], log_tfidf_f1[0],
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
